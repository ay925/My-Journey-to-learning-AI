# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list= [
    ['John', 'Anna', 'Peter', 'Linda'],
    [28, 34, 29, 42],
    ['New York', 'Paris', 'Berlin', 'London'],
    [65000, 70000, 62000, 85000]
]
df2=pd.DataFrame(data_list)
coloms=["Name","Age","city","salary"]
df2=pd.DataFrame(data_list,columns=coloms)
df2
# Out:
#        Name    Age    city  salary
# 0      John   Anna   Peter   Linda
# 1        28     34      29      42
# 2  New York  Paris  Berlin  London
# 3     65000  70000   62000   85000

# %%
df2
# Out:
#        Name    Age    city  salary
# 0      John   Anna   Peter   Linda
# 1        28     34      29      42
# 2  New York  Paris  Berlin  London
# 3     65000  70000   62000   85000

# %%
df2
# Out:
#        Name    Age    city  salary
# 0      John   Anna   Peter   Linda
# 1        28     34      29      42
# 2  New York  Paris  Berlin  London
# 3     65000  70000   62000   85000

# %%
df["Age"]
# Out:
# 0    28
# 1    34
# 2    29
# 3    42
# Name: Age, dtype: int64

# %%
df[["Name","Age"]]
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
df["Designation"]=["Doctor","Engineer","IAS","Police"]

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000         IAS
# 3  Linda   42    London   85000      Police

# %%
df.drop("Designation",axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selecting Rows

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000         IAS
# 3  Linda   42    London   85000      Police

# %%
df.loc[[0,1]]
# Out:
#    Name  Age      City  Salary Designation
# 0  John   28  New York   65000      Doctor
# 1  Anna   34     Paris   70000    Engineer

# %%
df.loc[[0,1]][["Age","Salary"]]
# Out:
#    Age  Salary
# 0   28   65000
# 1   34   70000

# %%
df.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000         IAS
# 3  Linda   42    London   85000      Police

# %%
df[(df["Age"]>30) & (df["City"]=="Paris")]
# Out:
#    Name  Age   City  Salary Designation
# 1  Anna   34  Paris   70000    Engineer
